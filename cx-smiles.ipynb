# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
IPythonConsole.ipython_useSVG=False  #< set this to False if you want PNGs instead of SVGs

# %%
sml_cx = "CO(C)[H]N1C=CC=C1 |H:3.2|"
m_cx = Chem.MolFromSmiles(sml_cx)
m_cx

# %%
sml = "CCCC |Sg:n:0,1,2:3-6:eu|"
m = Chem.MolFromSmiles(sml)
m

# %%
# Test in a kinase inhibitor
mol = Chem.MolFromSmiles("C1CC2=C3C(=CC=C2)C(=CN3C1)[C@H]4[C@@H](C(=O)NC4=O)C5=CNC6=CC=CC=C65")
# Default
mol

# %%
smi = 'c1nc(*)ccc1* |$;;;R1;;;;R2$|'
mol = Chem.MolFromSmiles(smi)
mol

# %%
m = Chem.MolFromSmiles('CO carbon monoxide')
m.GetProp('_Name')
# Out:
# 'carbon monoxide'
