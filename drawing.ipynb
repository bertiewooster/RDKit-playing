# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
from IPython.display import SVG
from rdkit.Chem.Draw import rdMolDraw2D

# smiles = 'C1=CC(=C(C=C1C2=C(C(=O)C3=C(C=C(C=C3O2)O)O)O)O)O'
# smiles = "C1=CC=CC=C1"
smiles = "C1C=CC=CC=1"
m = Chem.MolFromSmiles(smiles)

def moltosvg(mol, molSize = (300,300), kekulize = True):
    mc = Chem.Mol(mol.ToBinary())
    if kekulize:
        try:
            Chem.Kekulize(mc)
        except:
            mc = Chem.Mol(mol.ToBinary())
    if not mc.GetNumConformers():
        rdDepictor.Compute2DCoords(mc)
    drawer = rdMolDraw2D.MolDraw2DSVG(molSize[0],molSize[1])
    drawer.DrawMolecule(mc)
    drawer.FinishDrawing()
    svg = drawer.GetDrawingText()
    return svg.replace('svg:','')

SVG(moltosvg(m))

# %%
inchi = "InChI=1S/C28H60BrN/c1-5-9-13-17-21-25-30(29,26-22-18-14-10-6-2,27-23-19-15-11-7-3)28-24-20-16-12-8-4/h5-28H2,1-4H3"
Chem.MolFromInchi(inchi)
# Out:
# [22:31:27] Explicit valence for atom # 29 N, 5, is greater than permitted
# [22:31:27] ERROR: Explicit valence for atom # 29 N, 5, is greater than permitted

# %%
mol = Chem.MolFromInchi(inchi, sanitize=False)
mol

# %%
mol.Debug()
# Out:
# Atoms:
# 	0 6 C chg: 0  deg: 1 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	1 6 C chg: 0  deg: 1 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	2 6 C chg: 0  deg: 1 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	3 6 C chg: 0  deg: 1 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	4 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	5 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	6 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	7 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	8 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	9 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	10 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	11 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	12 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	13 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	14 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# 	15 6 C chg: 0  deg: 2 exp: 4 imp: 0 hyb: 0 arom?: 0 chi: 0
# ...

# %%
mol.GetA
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1