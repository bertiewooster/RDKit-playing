# %%
from rdkit import Chem

# %% [markdown]
# ## SMILES

# %%
# smiles = "[c:0]2[c:5][C:6]4([c:7]([c:8][c:9][c:10][c:11]6)[c:12]6[c:13]5[c:14]4[c:15][c:16][c:17][c:18]5)[c:19][c:20][O:25]2" # With labels
Chem.MolFromSmiles("c2cC4(c(cccc6)c6c5c4cccc5)cc[O]2")

# %%
# smiles = "[c:0]12[c:1][c:2][c:3][c:4][c:5]1[C:6]4([c:7]([c:8][c:9][c:10][c:11]6)[c:12]6[c:13]5[c:14]4[c:15][c:16][c:17][c:18]5)[c:19][c:20][O:25]2" # With labels
Chem.MolFromSmiles("c12ccccc1C4(c(cccc6)c6c5c4cccc5)ccO2")

# %%
# smiles = "[c:0]12[c:1][c:2][c:3][c:4][c:5]1[C:6]4([c:7]([c:8][c:9][c:10][c:11]6)[c:12]6[c:13]5[c:14]4[c:15][c:16][c:17][c:18]5)[c:19]3[c:20]([c:21][c:22][c:23][c:24]3)[O:25]2" # With labels
Chem.MolFromSmiles("c12ccccc1C4(c(cccc6)c6c5c4cccc5)c3c(cccc3)O2")

# %%
# Kekulized
Chem.MolFromSmiles("C12=CC=CC=C1C4(C(C=CC=C6)=C6C5=C4C=CC=C5)C3=C(C=CC=C3)O2")

# %% [markdown]
# ## SMARTS

# %%
# smarts = "[c:14]4[c:15][X][c:17][c:33][C:2]14[c:1]2[c:3]([c:4][c:5][c:6][c:7]2)[c:8]3[c:9]1[c:10][c:11][c:12][c:13]3" # With labels
smarts = "c4c[X]ccC14c2c(cccc2)c3c1cccc3"
Chem.MolFromSmarts(smarts)

# %%
# smarts = "[c:19]5[c:20][c:21][c:22][c:14]4[c:15]5[X][c:17][c:33][C:2]14[c:1]2[c:3]([c:4][c:5][c:6][c:7]2)[c:8]3[c:9]1[c:10][c:11][c:12][c:13]3" # With labels
smarts = "c5cccc4c5[X]ccC14c2c(cccc2)c3c1cccc3"
Chem.MolFromSmarts(smarts)

# %%
# smarts = "[c:19]5[c:20][c:21][c:22][c:14]4[c:15]5[X][c:17]6[c:18][c:30][c:31][c:32][c:33]6[C:2]14[c:1]2[c:3]([c:4][c:5][c:6][c:7]2)[c:8]3[c:9]1[c:10][c:11][c:12][c:13]3" # With labels
Chem.MolFromSmarts("c5cccc4c5[X]c6ccccc6C14c2c(cccc2)c3c1cccc3")
