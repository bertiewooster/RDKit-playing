# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Geometry import Point2D
from IPython.display import display, SVG

# %%
# Create a molecule from SMILES
Chem.MolFromSmiles('O[Mn@OH10](Cl)(C)(N)(F)')

# %%
Chem.MolFromSmiles('O[Mn@OH1](Cl)(C)(N)(F)')

# %%
Chem.MolFromSmiles('O[Mn@OH28](Cl)(C)(N)F')

# %%
    ('O[Mn@OH28](*)(Cl)(C)(N)F')
# Out:
# 'O[Mn@OH28](*)(Cl)(C)(N)F'

# %%
Chem.MolFromSmiles('COC(=O)C1C(c2ccccc2)C(C(=O)OC)C1c1ccc(Br)cc1')
