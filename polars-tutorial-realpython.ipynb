# %% [markdown]
# # [Python Polars: A Lightning-Fast DataFrame Library](https://realpython.com/polars-python/)

# %% [markdown]
# ## [DataFrames, Expressions, and Contexts](https://realpython.com/polars-python/#dataframes-expressions-and-contexts)

# %%
import numpy as np
import polars as pl

num_rows = 5000
rng = np.random.default_rng(seed=7)

buildings_data = {
     "sqft": rng.exponential(scale=1000, size=num_rows),
     "year": rng.integers(low=1995, high=2023, size=num_rows),
     "building_type": rng.choice(["A", "B", "C"], size=num_rows),
 }
buildings = pl.DataFrame(buildings_data)
buildings
# Out:
# shape: (5000, 3)
# ┌─────────────┬──────┬───────────────┐
# │ sqft        ┆ year ┆ building_type │
# │ ---         ┆ ---  ┆ ---           │
# │ f64         ┆ i64  ┆ str           │
# ╞═════════════╪══════╪═══════════════╡
# │ 707.529256  ┆ 1996 ┆ C             │
# │ 1025.203348 ┆ 2020 ┆ C             │
# │ 568.548657  ┆ 2012 ┆ A             │
# │ 895.109864  ┆ 2000 ┆ A             │
# │ ...         ┆ ...  ┆ ...           │
# │ 408.872783  ┆ 2009 ┆ C             │
# │ 57.562059   ┆ 2019 ┆ C             │
# │ 3728.088949 ┆ 2020 ┆ C             │
# │ 686.678345  ┆ 2011 ┆ C             │
# └─────────────┴──────┴───────────────┘

# %%
buildings.schema
# Out:
# {'sqft': Float64, 'year': Int64, 'building_type': Utf8}

# %%
buildings.head()
# Out:
# shape: (5, 3)
# ┌─────────────┬──────┬───────────────┐
# │ sqft        ┆ year ┆ building_type │
# │ ---         ┆ ---  ┆ ---           │
# │ f64         ┆ i64  ┆ str           │
# ╞═════════════╪══════╪═══════════════╡
# │ 707.529256  ┆ 1996 ┆ C             │
# │ 1025.203348 ┆ 2020 ┆ C             │
# │ 568.548657  ┆ 2012 ┆ A             │
# │ 895.109864  ┆ 2000 ┆ A             │
# │ 206.532754  ┆ 2011 ┆ A             │
# └─────────────┴──────┴───────────────┘

# %%
buildings.describe()
# Out:
# shape: (7, 4)
# ┌────────────┬─────────────┬───────────┬───────────────┐
# │ describe   ┆ sqft        ┆ year      ┆ building_type │
# │ ---        ┆ ---         ┆ ---       ┆ ---           │
# │ str        ┆ f64         ┆ f64       ┆ str           │
# ╞════════════╪═════════════╪═══════════╪═══════════════╡
# │ count      ┆ 5000.0      ┆ 5000.0    ┆ 5000          │
# │ null_count ┆ 0.0         ┆ 0.0       ┆ 0             │
# │ mean       ┆ 994.094456  ┆ 2008.5258 ┆ null          │
# │ std        ┆ 1016.641569 ┆ 8.062353  ┆ null          │
# │ min        ┆ 1.133256    ┆ 1995.0    ┆ A             │
# │ max        ┆ 9307.793917 ┆ 2022.0    ┆ C             │
# │ median     ┆ 669.370932  ┆ 2009.0    ┆ null          │
# └────────────┴─────────────┴───────────┴───────────────┘

# %%
buildings.select("sqft")
# Out:
# shape: (5000, 1)
# ┌─────────────┐
# │ sqft        │
# │ ---         │
# │ f64         │
# ╞═════════════╡
# │ 707.529256  │
# │ 1025.203348 │
# │ 568.548657  │
# │ 895.109864  │
# │ ...         │
# │ 408.872783  │
# │ 57.562059   │
# │ 3728.088949 │
# │ 686.678345  │
# └─────────────┘

# %%
buildings.select(pl.col("sqft"))
# Out:
# shape: (5000, 1)
# ┌─────────────┐
# │ sqft        │
# │ ---         │
# │ f64         │
# ╞═════════════╡
# │ 707.529256  │
# │ 1025.203348 │
# │ 568.548657  │
# │ 895.109864  │
# │ ...         │
# │ 408.872783  │
# │ 57.562059   │
# │ 3728.088949 │
# │ 686.678345  │
# └─────────────┘

# %%
buildings.select(pl.col("sqft").sort() / 1000)
# Out:
# shape: (5000, 1)
# ┌──────────┐
# │ sqft     │
# │ ---      │
# │ f64      │
# ╞══════════╡
# │ 0.001133 │
# │ 0.001152 │
# │ 0.001429 │
# │ 0.001439 │
# │ ...      │
# │ 7.247539 │
# │ 7.629569 │
# │ 8.313942 │
# │ 9.307794 │
# └──────────┘

# %%
after_2015 = buildings.filter(pl.col("year") > 2015)
after_2015.shape
# Out:
# (1230, 3)

# %%
after_2015.select(pl.col("year").min())
# Out:
# shape: (1, 1)
# ┌──────┐
# │ year │
# │ ---  │
# │ i64  │
# ╞══════╡
# │ 2016 │
# └──────┘

# %%
buildings.groupby("building_type").agg(
    [
        pl.mean("sqft").alias("mean_sqft"),
        pl.max("sqft").alias("max_sqft"),
        pl.median("year").alias("median_year"),
        pl.count(),
    ]
)
# Out:
# shape: (3, 5)
# ┌───────────────┬────────────┬─────────────┬─────────────┬───────┐
# │ building_type ┆ mean_sqft  ┆ max_sqft    ┆ median_year ┆ count │
# │ ---           ┆ ---        ┆ ---         ┆ ---         ┆ ---   │
# │ str           ┆ f64        ┆ f64         ┆ f64         ┆ u32   │
# ╞═══════════════╪════════════╪═════════════╪═════════════╪═══════╡
# │ C             ┆ 999.854722 ┆ 9307.793917 ┆ 2009.0      ┆ 1692  │
# │ B             ┆ 992.754444 ┆ 8313.942444 ┆ 2009.0      ┆ 1655  │
# │ A             ┆ 989.539918 ┆ 7247.538867 ┆ 2009.0      ┆ 1653  │
# └───────────────┴────────────┴─────────────┴─────────────┴───────┘

# %% [markdown]
# ## [The Lazy API](https://realpython.com/polars-python/#the-lazy-api)

# %%
# !pip install polars -U
# Out:
# Requirement already satisfied: polars in ./venv/lib/python3.11/site-packages (0.20.9)

# %%
num_rows = 5000
rng = np.random.default_rng(seed=7)

buildings = {
     "sqft": rng.exponential(scale=1000, size=num_rows),
     "price": rng.exponential(scale=100_000, size=num_rows),
     "year": rng.integers(low=1995, high=2023, size=num_rows),
     "building_type": rng.choice(["A", "B", "C"], size=num_rows),
  }
buildings_lazy = pl.LazyFrame(buildings)
buildings_lazy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 10
#       2 rng = np.random.default_rng(seed=7)
#       4 buildings = {
#       5      "sqft": rng.exponential(scale=1000, size=num_rows),
#       6      "price": rng.exponential(scale=100_000, size=num_rows),
#       7      "year": rng.integers(low=1995, high=2023, size=num_rows),
#       8      "building_type": rng.choice(["A", "B", "C"], size=num_rows),
#       9   }
# ---> 10 buildings_lazy = pl.LazyFrame(buildings)
#      11 buildings_lazy
#
# TypeError: LazyFrame() takes no arguments

# %%
data = {"a": [1, 2], "b": [3, 4]}
lf = pl.LazyFrame(data=data)
lf.collect()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 data = {"a": [1, 2], "b": [3, 4]}
# ----> 2 lf = pl.LazyFrame(data=data)
#       3 lf.collect()
#
# TypeError: LazyFrame() takes no arguments
